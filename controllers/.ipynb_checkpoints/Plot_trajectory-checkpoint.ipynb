# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data = {}
colors = ["", "red", "blue", "black", "yellow", "purple"]
for i in range(1, 6):
    data[i] = np.load(str(i) + ".npy")
data[1][:10]
# Out:
# array([[-0.06602824, -0.16911946],
#        [-0.06609898, -0.16741441],
#        [-0.06617568, -0.16656261],
#        [-0.06628379, -0.16571618],
#        [-0.06864674, -0.15757448],
#        [-0.06939653, -0.15604667],
#        [-0.07022963, -0.15456518],
#        [-0.07162349, -0.15243932],
#        [-0.07318797, -0.15044054],
#        [-0.07374663, -0.14980473]])

# %%
x,y = data[1].T
y[:10]
# Out:
# array([-0.16911946, -0.16741441, -0.16656261, -0.16571618, -0.15757448,
#        -0.15604667, -0.15456518, -0.15243932, -0.15044054, -0.14980473])

# %%
plt.figure(figsize=(16, 12))
for i in range(1, 6):
    x,y = data[i].T
    plt.plot(x, -y, color = colors[i], label = "robot_" + str(i))
plt.axis('equal')
plt.legend()
plt.show()
